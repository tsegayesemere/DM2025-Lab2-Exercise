# %% [markdown]
# ### **Student Information**
# Name:
#
# Student ID:
#
# GitHub ID:
#
# Kaggle name:
#
# Kaggle private scoreboard snapshot:
#
# ![pic_ranking.png](./pics/pic_ranking.png)

# %% [markdown]
# ---

# %% [markdown]
# # **Instructions**

# %% [markdown]
# For this lab we have divided the assignments into **three phases/parts**. The `first two phases` refer to the `exercises inside the Master notebooks` of the [DM2025-Lab2-Exercise Repo](https://github.com/difersalest/DM2025-Lab2-Exercise.git). The `third phase` refers to an `internal Kaggle competition` that we are gonna run among all the Data Mining students. Together they add up to `100 points` of your grade. There are also some `bonus points` to be gained if you complete `extra exercises` in the lab **(bonus 15 pts)** and in the `Kaggle Competition report` **(bonus 5 pts)**.
#
# **Environment recommendations to solve lab 2:**
# - **Phase 1 exercises:** Need GPU for training the models explained in that part, if you don't have a GPU in your laptop it is recommended to run in Colab or Kaggle for a faster experience, although with CPU they can still be solved but with a slower execution.
# - **Phase 2 exercises:** We use Gemini's API so everything can be run with only CPU without a problem.
# - **Phase 3 exercises:** For the competition you will probably need GPU to train your models, so it is recommended to use Colab or Kaggle if you don't have a laptop with a dedicated GPU.
# - **Optional Ollama Notebook (not graded):** You need GPU, at least 4GB of VRAM with 16 GB of RAM to run the local open-source LLM models.
#
# ## **Phase 1 (30 pts):**
#
# 1. __Main Exercises (25 pts):__ Do the **take home exercises** from Sections: `1. Data Preparation` to `9. High-dimension Visualization: t-SNE and UMAP`, in the [DM2025-Lab2-Master-Phase_1 Notebook](https://github.com/difersalest/DM2025-Lab2-Exercise/blob/main/DM2025-Lab2-Master-Phase_1.ipynb). Total: `8 exercises`. Commit your code and submit the repository link to NTU Cool **`BEFORE the deadline (Nov. 3th, 11:59 pm, Monday)`**
#
# 2. **Code Comments (5 pts):** **Tidy up the code in your notebook**.
#
# ## **Phase 2 (30 pts):**
#
# 1. **Main Exercises (25 pts):** Do the remaining **take home exercises** from Section: `2. Large Language Models (LLMs)` in the [DM2025-Lab2-Master-Phase_2_Main Notebook](https://github.com/difersalest/DM2025-Lab2-Exercise/blob/main/DM2025-Lab2-Master-Phase_2_Main.ipynb). Total: `5 exercises required from sections 2.1, 2.2, 2.4 and 2.6`. Commit your code and submit the repository link to NTU Cool **`BEFORE the deadline (Nov. 24th, 11:59 pm, Monday)`**
#
# 2. **Code Comments (5 pts):** **Tidy up the code in your notebook**.
#
# 3. **`Bonus (15 pts):`** Complete the bonus exercises in the [DM2025-Lab2-Master-Phase_2_Bonus Notebook](https://github.com/difersalest/DM2025-Lab2-Exercise/blob/main/DM2025-Lab2-Master-Phase_2_Bonus.ipynb) and [DM2025-Lab2-Master-Phase_2_Main Notebook](https://github.com/difersalest/DM2025-Lab2-Exercise/blob/main/DM2025-Lab2-Master-Phase_2_Main.ipynb) `where 2 exercises are counted as bonus from sections 2.3 and 2.5 in the main notebook`. Total: `7 exercises`. Commit your code and submit the repository link to NTU Cool **`BEFORE the deadline (Nov. 24th, 11:59 pm, Monday)`**
#
# ## **Phase 3 (40 pts):**
#
# 1. **Kaggle Competition Participation (30 pts):** Participate in the in-class **Kaggle Competition** regarding Emotion Recognition on Twitter by clicking in this link: **[Data Mining Class Kaggle Competition](https://www.kaggle.com/t/3a2df4c6d6b4417e8bf718ed648d7554)**. The scoring will be given according to your place in the Private Leaderboard ranking:
#     - **Bottom 40%**: Get 20 pts of the 30 pts in this competition participation part.
#
#     - **Top 41% - 100%**: Get (0.6N + 1 - x) / (0.6N) * 10 + 20 points, where N is the total number of participants, and x is your rank. (ie. If there are 100 participants and you rank 3rd your score will be (0.6 * 100 + 1 - 3) / (0.6 * 100) * 10 + 20 = 29.67% out of 30%.)
#     Submit your last submission **`BEFORE the deadline (Nov. 24th, 11:59 pm, Monday)`**. Make sure to take a screenshot of your position at the end of the competition and store it as `pic_ranking.png` under the `pics` folder of this repository and rerun the cell **Student Information**.
#
# 2. **Competition Report (10 pts)** A report section to be filled in inside this notebook in Markdown Format, we already provided you with the template below. You need to describe your work developing the model for the competition. The report should include a section describing briefly the following elements:
# * Your preprocessing steps.
# * The feature engineering steps.
# * Explanation of your model.
#
# * **`Bonus (5 pts):`**
#     * You will have to describe more detail in the previous steps.
#     * Mention different things you tried.
#     * Mention insights you gained.
#
# [Markdown Guide - Basic Syntax](https://www.markdownguide.org/basic-syntax/)
#
# **`Things to note for Phase 3:`**
#
# * **The code used for the competition should be in this Jupyter Notebook File** `DM2025-Lab2-Homework.ipynb`.
#
# * **Push the code used for the competition to your repository**.
#
# * **The code should have a clear separation for the same sections of the report, preprocessing, feature engineering and model explanation. Briefly comment your code for easier understanding, we provide a template at the end of this notebook.**
#
# * Showing the kaggle screenshot of the ranking plus the code in this notebook will ensure the validity of your participation and the report to obtain the corresponding points.
#
# After the competition ends you will have two days more to submit the `DM2025-Lab2-Homework.ipynb` with your report in markdown format and your code. Do everything **`BEFORE the deadline (Nov. 26th, 11:59 pm, Wednesday) to obtain 100% of the available points.`**
#
# Upload your files to your repository then submit the link to it on the corresponding NTU Cool assignment.
#
# ## **Deadlines:**
#
# ![lab2_deadlines](./pics/lab2_deadlines.png)

# %% [markdown]
# ---
#
# Next you will find the template report with some simple markdown syntax explanations, use it to structure your content.
#
# You can delete the syntax suggestions after you use them.
#
# ---

# %% [markdown]
# ***
#
# # **Project Report**
#
# **Syntax:** `#` creates the largest heading (H1).
#
# ---
# **Syntax:** `---` creates a horizontal rule (a separator line).
#
# ## 1. Model Development (10 pts Required)
#
# **Syntax:** `##` creates a secondary heading (H2).
#
# **Describe briefly each section, you can add graphs/charts to support your explanations.**
#
# ### 1.1 Preprocessing Steps
#
# **Syntax:** `###` creates a tertiary heading (H3).
#
# [Content for Preprocessing]
#
# **Example Syntax for Content:**
# *   **Bold text:** `**text**`
# *   *Italic text*: `*text*`
# *   Bullet point list:
#     * Item 1
#     * Item 2
#
# Markdown Syntax to Add Image: `![Description of the Image](./your_local_folder/name_of_the_image.png)`
#
# ![Example Markdown Syntax to Add Image](./pics/example_md_img.png)
#
# ### 1.2 Feature Engineering Steps
#
# [Content for Feature Engineering]
#
# ### 1.3 Explanation of Your Model
#
# [Content for Model Explanation]
#
# ---
#
# ## 2. Bonus Section (5 pts Optional)
#
# **Add more detail in previous sections**
#
# ### 2.1 Mention Different Things You Tried
#
# [Content for Experiments]
#
# ### 2.2 Mention Insights You Gained
#
# [Content for Insights]
#
# ---

# %% [markdown]
# **`From here on starts the code section for the competition.`**
#
# ---

# %% [markdown]
# # **Competition Code**
#
# ## 1. Preprocessing Steps

# %%
import json
from pandas import json_normalize
import pandas as pd

with open("data/phaseIII/final_posts.json", "r", encoding="utf-8") as f: # load the json file from my local drive
    post = json.load(f)

post = pd.DataFrame([
    {
        "post_id": item["root"]["_source"]["post"]["post_id"],
        "text": item["root"]["_source"]["post"]["text"]
    }
    for item in post
])

post.to_csv("data/phaseIII/2posts.csv", index=False) # convert the json file in to csv for future use

# %%
#load all csv files 
emotion = pd.read_csv("data/phaseIII/emotion.csv")
split = pd.read_csv("data/phaseIII/data_identification.csv")
post = pd.read_csv("data/phaseIII/posts.csv")

# %%
emotion.head()
# Out:
#          id emotion
# 0  0x35663e     joy
# 1  0xc78afe    fear
# 2  0x90089c     joy
# 3  0x2ffb63     joy
# 4  0x989146     joy

# %%
split.head()
# Out:
#          id  split
# 0  0x61fc95   test
# 1  0x35663e  train
# 2  0xc78afe  train
# 3  0x90089c  train
# 4  0xaba820   test

# %%
post.head()
# Out:
#     post_id                                               text
# 0  0x61fc95  We got the ranch, loaded our guns and sat up t...
# 1  0x35663e  I bet there is an army of married couples who ...
# 2  0xc78afe                         This could only end badly.
# 3  0x90089c  My sister squeezed a lime in her milk when she...
# 4  0xaba820         and that got my head bobbing a little bit.

# %%
# Rename post_id to id. Just for consistency
post.rename(columns={"post_id": "id"}, inplace=True)
post.head()
# Out:
#          id                                               text
# 0  0x61fc95  We got the ranch, loaded our guns and sat up t...
# 1  0x35663e  I bet there is an army of married couples who ...
# 2  0xc78afe                         This could only end badly.
# 3  0x90089c  My sister squeezed a lime in her milk when she...
# 4  0xaba820         and that got my head bobbing a little bit.

# %%
# merge the file in to one datafram (id,text,emotion,split)
Full_data_frame = pd.merge(post, emotion, on='id', how='outer')
Full_data_frame = pd.merge(Full_data_frame, split, on='id', how='outer')

Full_data_frame.to_csv("data/phaseIII/Full_data.csv") # store the combined dataframe in local disk for future use
Full_data_frame = pd.read_csv("data/phaseIII/Full_data.csv") # Appload the saved combined dataframe
Full_data_frame.head()
# Out:
#    Unnamed: 0        id                                               text  \
# 0           0  0x000036   Everyone calling you out but not if you’re right
# 1           1  0x00003f  Relatives nowadays only cling if you’re capabl...
# 2           2  0x000063                                  It never came up.
# 3           3  0x0002d7             And I though Glory Kills were gruesome
# 4           4  0x0004f6  Tomorrow, is the FIRST DAY OF 🍂🍂FALL🍁🍁and I'm ...
#
#     emotion  split
# 0  surprise  train
# 1     anger  train
# 2  surprise  train
# 3   disgust  train
# 4       joy  train

# %%
import pandas as pd
Full_data_frame = pd.read_csv("data/phaseIII/Full_data.csv") # Appload the saved combined dataframe

# %%
len(Full_data_frame)
# Out:
# 64171

# %%
Full_data_frame['text_clean'] = (
    Full_data_frame['text']
        .astype(str)
        .str.replace(r'([^\w\s])\1+', r'\1', regex=True)
        .str.lower()
)

# %%
# As we can see on the graph, few words (stop words) have highest frequency. As they do not help to make predicitons, we better remove them
from collections import Counter

# Combine all text into one lowercase string
all_text = " ".join(Full_data_frame["text_clean"].astype(str)).lower()

# Split by whitespace
words = all_text.split()

# Count frequency
overall_freq = Counter(words)
high_freq_words = {w for w, c in overall_freq.items() if c > 10000}
len(high_freq_words), list(high_freq_words)
# Out:
# (2, ['of', 'that'])

# %%
# Let's see the frequency of words in a graph
import re
from collections import Counter
import matplotlib.pyplot as plt

all_text = " ".join(Full_data_frame["text_clean"].astype(str))

# Convert to lowercase
all_text = all_text.lower()

# Split into words
words = all_text.split()
word_freq = Counter(words)

word_freq_df = pd.DataFrame(word_freq.items(), columns=["word", "frequency"])
word_freq_df = word_freq_df.sort_values(by="frequency", ascending=False).reset_index(drop=True)

word_freq_df = (
    pd.DataFrame(word_freq.items(), columns=["word", "frequency"])
    .sort_values(by="frequency", ascending=False)
    .reset_index(drop=True)
)


top_n = 350
top_words = word_freq_df.head(top_n)

plt.figure(figsize=(12,6))
plt.bar(top_words["word"], top_words["frequency"])
plt.xticks(rotation=45, ha="right")
plt.xlabel("Words")
plt.ylabel("Frequency")
plt.title(f"Top {top_n} Most Frequent Words in train_df['text']")
plt.tight_layout()
plt.show()

# %%
def remove_most_freqs(text):
    tokens = text.lower().split()
    cleaned_tokens = [w for w in tokens if w not in high_freq_words]
    return " ".join(cleaned_tokens)

# Create cleaned column
Full_data_frame["text_clean"] = Full_data_frame["text_clean"].astype(str).apply(remove_most_freqs)

# %%
test_df = Full_data_frame[Full_data_frame["split"] == "test"] # Separate the test split and train split in to different dataframes
train_df = Full_data_frame[Full_data_frame["split"] == "train"]

# %%
len(test_df) # which should be equeal to the size of the sample submission data set
# Out:
# 16281

# %%
len(train_df)
# Out:
# 47890

# %%
train_df=train_df[["id","text_clean","emotion"]] # Filter only relevant columns for each split. because Unnamed: 0,is not important here
test_df=test_df[["id","text_clean"]] # emotion is not give for test dataset

# %%
# shuffle dataset
train_df = train_df.sample(frac=1)
test_df = test_df.sample(frac=1)

# %%
print("Shape of Training df: ", train_df.shape)
print("Shape of Testing df: ", test_df.shape)
# Out:
# Shape of Training df:  (47890, 3)
# Shape of Testing df:  (16281, 2)

# %%
# save both dataframs to pickle file
train_df.to_pickle("./data/train_df_2.pkl") 
test_df.to_pickle("./data/test_df_2.pkl")

# %%
## load a pickle file
train_df = pd.read_pickle("./data/train_df_2.pkl")
test_df = pd.read_pickle("./data/test_df_2.pkl")

# %%
# Let's see the frequency of words in a graph
import re
from collections import Counter
import matplotlib.pyplot as plt

all_text = " ".join(train_df["text"].astype(str))

# Convert to lowercase
all_text = all_text.lower()

# Split into words
words = all_text.split()
word_freq = Counter(words)

word_freq_df = pd.DataFrame(word_freq.items(), columns=["word", "frequency"])
word_freq_df = word_freq_df.sort_values(by="frequency", ascending=False).reset_index(drop=True)

word_freq_df = (
    pd.DataFrame(word_freq.items(), columns=["word", "frequency"])
    .sort_values(by="frequency", ascending=False)
    .reset_index(drop=True)
)


top_n = 350
top_words = word_freq_df.head(top_n)

plt.figure(figsize=(12,6))
plt.bar(top_words["word"], top_words["frequency"])
plt.xticks(rotation=45, ha="right")
plt.xlabel("Words")
plt.ylabel("Frequency")
plt.title(f"Top {top_n} Most Frequent Words in train_df['text']")
plt.tight_layout()
plt.show()

# %%
top_n = 50
top_words = word_freq_df.head(top_n)

plt.figure(figsize=(12,6))
plt.bar(top_words["word"], top_words["frequency"])
plt.xticks(rotation=45, ha="right")
plt.xlabel("Words")
plt.ylabel("Frequency")
plt.title(f"Top {top_n} Most Frequent Words in train_df['text']")
plt.tight_layout()
plt.show()

# %%
# As we can see on the graph, few words (stop words) have highest frequency. As they do not help to make predicitons, we better remove them
from collections import Counter

# Combine all text into one lowercase string
all_text = " ".join(train_df["text"].astype(str)).lower()

# Split by whitespace
words = all_text.split()

# Count frequency
overall_freq = Counter(words)
high_freq_words = {w for w, c in overall_freq.items() if c > 2000}
len(high_freq_words), list(high_freq_words)
# Out:
# (40,
#  ['it',
#   'like',
#   'that',
#   'and',
#   'just',
#   'be',
#   'what',
#   'so',
#   'you',
#   'in',
#   "it's",
#   '[name]',
#   "i'm",
#   'are',
#   'this',
#   'a',
#   'they',
#   'i',
#   'to',
#   'about',
#   'he',
#   'the',
#   'but',
#   'all',
#   'me',
#   'have',
#   'was',
#   'my',
#   'get',
#   'as',
#   'on',
#   'with',
#   'for',
#   'we',
#   'is',
#   'your',
#   'not',
#   'of',
#   'if',
#   'at'])

# %%
# so now let's remove them and store the cleaned text in new colomun called "clean_text"
def remove_most_freqs(text):
    tokens = text.lower().split()
    cleaned_tokens = [w for w in tokens if w not in high_freq_words]
    return " ".join(cleaned_tokens)

# Create cleaned column
train_df["clean_text"] = train_df["text"].astype(str).apply(remove_most_freqs)

# %%
# Let's regenerate our frequency graph to see the difference 
# Let's see the frequency of words in a graph
import re
from collections import Counter
import matplotlib.pyplot as plt

all_text = " ".join(train_df["text_clean"].astype(str))

# Convert to lowercase
all_text = all_text.lower()

# Split into words
words = all_text.split()
word_freq = Counter(words)

word_freq_df = pd.DataFrame(word_freq.items(), columns=["word", "frequency"])
word_freq_df = word_freq_df.sort_values(by="frequency", ascending=False).reset_index(drop=True)

word_freq_df = (
    pd.DataFrame(word_freq.items(), columns=["word", "frequency"])
    .sort_values(by="frequency", ascending=False)
    .reset_index(drop=True)
)


top_n = 350
top_words = word_freq_df.head(top_n)

plt.figure(figsize=(12,6))
plt.bar(top_words["word"], top_words["frequency"])
plt.xticks(rotation=45, ha="right")
plt.xlabel("Words")
plt.ylabel("Frequency")
plt.title(f"Top {top_n} Most Frequent Words in train_df['text']")
plt.tight_layout()
plt.show()

# %%
# Let's do the same thing for our test dataset
test_df["text_clean"] = test_df["text"].astype(str).apply(remove_most_freqs)

# %%
train_df.head()
# Out:
#              id                                         text_clean emotion
# 31630  0x7e61a3  yard goats was awesome. almost major league fe...     joy
# 64031  0xff767e  im just glad it didn't take any for us. i'm gl...     joy
# 37911  0x97de9c  heard our county head just took office. funny ...   anger
# 19861  0x4ffffe  oh wow thank all for your opinions, was just c...     joy
# 47788  0xbe9067  it's probably better just subscribe scotch or ...     joy

# %%
test_df.head()
# Out:
#              id                                         text_clean
# 28208  0x70bfb6  shenzhen has been like this for year now. even...
# 10303  0x29b53d  love how there isn't single legit trade in thi...
# 63593  0xfda493  what meant was, penalty for being convicted bo...
# 58143  0xe7fb38  confidential document from henan’s health comm...
# 2681   0x0a5a1c          can't tell if this happy or sad ending. 😐

# %%
# Lets plote a graph that shown emotion distribution 
from colorama import Fore, Back, Style
print (Fore.BLACK + Back.YELLOW + "for X" + Style.RESET_ALL)
train_df.emotion.value_counts().plot(kind = 'bar',
                                    title = 'Emotion distribution',
                                    rot = 0, fontsize = 11, figsize = (8,3))
# Out:
# for X
# <Axes: title={'center': 'Emotion distribution'}, xlabel='emotion'>

# %%
def downsample(train_df, emotion, new_size):
    return train_df[train_df["emotion"] == emotion].sample(new_size, random_state=42)

df_new = pd.concat([
    downsample(train_df, "joy", 9898), # Reduced by 50%
    train_df[train_df["emotion"]=="anger"],
    train_df[train_df["emotion"]=="surprise"],   
    train_df[train_df["emotion"]=="sadness"],     
    train_df[train_df["emotion"]=="fear"],
    train_df[train_df["emotion"]=="disgust"]
])

train_df = df_new.sample(frac=1, random_state=42)  # shuffle

# %% [markdown]
# ## 2. Feature Engineering Steps

# %%
# Let's do embeding next
import ollama

# Define a function to generate embeddings
def generate_embeddings(row,text_column_name='text_clean'):
    embeddings = ollama.embeddings(
        model='nomic-embed-text',
        prompt=row[text_column_name],
    )
    return embeddings["embedding"]

# %%
column_name = 'text_clean'
train_df['embeddings'] = train_df.apply(lambda row: generate_embeddings(row, column_name), axis=1)

# %%
train_df.to_csv("train_df_with_embeddings_3.csv")

# %%
column_name = 'text_clean'
test_df['embeddings'] = test_df.apply(lambda row: generate_embeddings(row, column_name), axis=1)
test_df.to_csv("test_df_with_embeddings_3.csv")

# %%
# Lets plote a graph that shown emotion distribution 
from colorama import Fore, Back, Style
print (Fore.BLACK + Back.YELLOW + "for X" + Style.RESET_ALL)
train_df.emotion.value_counts().plot(kind = 'bar',
                                    title = 'Emotion distribution',
                                    rot = 0, fontsize = 11, figsize = (8,3))
# Out:
# for X
# <Axes: title={'center': 'Emotion distribution'}, xlabel='emotion'>

# %%
# Lets down sample joy and over sample the rest to solve unbalanced class labels  
'''from sklearn.utils import resample

# Separate majority and minority classes
df_majority = train_df[train_df['emotion'] == 'joy']
df_minority = train_df[train_df['emotion'] != 'joy']

# Find the maximum class count (we will oversample others to match this)
max_count = train_df['emotion'].value_counts().max()

# Oversample each minority class
df_list = [df_majority]  # start with majority

for emotion in train_df['emotion'].unique():
    if emotion != 'joy':
        df_em = train_df[train_df['emotion'] == emotion]
        df_em_over = resample(df_em,
                              replace=True,       # sample with replacement
                              n_samples=max_count, # match majority class
                              random_state=42)
        df_list.append(df_em_over)

# Combine all
df_train_balanced = pd.concat(df_list)

# Shuffle
df_train_balanced = df_train_balanced.sample(frac=1, random_state=42).reset_index(drop=True)

# Check new distribution
df_train_balanced['emotion'].value_counts()'''
# Out:
# "from sklearn.utils import resample\n\n# Separate majority and minority classes\ndf_majority = train_df[train_df['emotion'] == 'joy']\ndf_minority = train_df[train_df['emotion'] != 'joy']\n\n# Find the maximum class count (we will oversample others to match this)\nmax_count = train_df['emotion'].value_counts().max()\n\n# Oversample each minority class\ndf_list = [df_majority]  # start with majority\n\nfor emotion in train_df['emotion'].unique():\n    if emotion != 'joy':\n        df_em = train_df[train_df['emotion'] == emotion]\n        df_em_over = resample(df_em,\n                              replace=True,       # sample with replacement\n                              n_samples=max_count, # match majority class\n                              random_state=42)\n        df_list.append(df_em_over)\n\n# Combine all\ndf_train_balanced = pd.concat(df_list)\n\n# Shuffle\ndf_train_balanced = df_train_balanced.sample(frac=1, random_state=42).reset_index(drop=True)\n\n# Check new distribution\ndf_train_balanced['emotion'].value_counts()"

# %%
from sklearn.model_selection import train_test_split
train_df_or = train_df.copy()
df_train_train, df_train_test = train_test_split(train_df, test_size=0.20, random_state=42)

# %%
df_train_test = df_train_test[df_train_test["embeddings"].apply(lambda x: len(x) == 768)]
df_train_test = df_train_test.reset_index(drop=True)
train_df_or = train_df_or[train_df_or["embeddings"].apply(lambda x: len(x) == 768)]
train_df_or = train_df_or.reset_index(drop=True)

# %%
import numpy as np
X_embgemma_train = np.vstack(train_df_or["embeddings"].to_numpy()) #Defining our train set
##X_embgemma_train = np.vstack(df_train_train["embeddings"].to_numpy()) #Defining our train set

X_embgemma_test = np.vstack(df_train_test["embeddings"].to_numpy()) #Defining our test set

# %%
X_embgemma_train.shape #(Number of data, embeddinggemma embedding size)
# Out:
# (33991, 768)

# %%
X_embgemma_test.shape #(Number of data, embeddinggemma embedding size)
# Out:
# (6799, 768)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# Let's use the new embeddinggemma embeddings as our training features and the emotions as our labels
##X_train = df_train_train["embeddings"].tolist()
X_train = train_df_or["embeddings"].tolist()

y_train = train_df_or['emotion']


# Initialize the KNN classifier
knn = KNeighborsClassifier(n_neighbors=10)

knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=10)

# %%
X_test = df_train_test["embeddings"].tolist()
y_test = df_train_test['emotion']

# Predicting the label for the test data
y_pred = knn.predict(X_test)

#Calculate the accuracy of the model
accuracy = accuracy_score(y_test, y_pred)

print(f'KNN Accuracy: {accuracy}')
# Out:
# KNN Accuracy: 0.5856743638770407

# %%
# deal with label (string -> one-hot)
import keras
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
label_encoder.fit(y_train)

print('check label: ', label_encoder.classes_)
print('\n## Before convert')
print('y_train[0:6]:\n', y_train[0:6])
print('\ny_train.shape: ', y_train.shape)
print('y_test.shape: ', y_test.shape)

def label_encode(le, labels):
    enc = le.transform(labels)
    return keras.utils.to_categorical(enc)

def label_decode(le, one_hot_label):
    dec = np.argmax(one_hot_label, axis=1)
    return le.inverse_transform(dec)
# Out:
# check label:  ['anger' 'disgust' 'fear' 'joy' 'sadness' 'surprise']
#
# ## Before convert
# y_train[0:6]:
#  0         joy
# 1    surprise
# 2       anger
# 3         joy
# 4         joy
# 5         joy
# Name: emotion, dtype: object
#
# y_train.shape:  (33991,)
# y_test.shape:  (6799,)

# %%
#One-hot encoding our labels
##y_train = df_train_train["emotion"]
y_train = train_df_or["emotion"]

y_test  = df_train_test["emotion"]
y_train_embgemma = label_encode(label_encoder, y_train)  
y_test_embgemma = label_encode(label_encoder, y_test)

# %%
# I/O check
input_shape_embgemma = len(X_embgemma_train[0])
print('input_shape: ', input_shape_embgemma)

output_shape = len(label_encoder.classes_)
print('output_shape: ', output_shape)
# Out:
# input_shape:  768
# output_shape:  6

# %%
#We try the same Neural Network Model Again
from keras.models import Model
from keras.layers import Input, Dense
from keras.layers import ReLU, Softmax

# input layer
model_input = Input(shape=(input_shape_embgemma, ))  # 3072
X = model_input

# 1st hidden layer
X_W1 = Dense(units=64)(X)  # 64
H1 = ReLU()(X_W1)

# 2nd hidden layer
H1_W2 = Dense(units=64)(H1)  # 64
H2 = ReLU()(H1_W2)

# output layer
H2_W3 = Dense(units=output_shape)(H2)  # 4
H3 = Softmax()(H2_W3)

model_output = H3

# create model
model = Model(inputs=[model_input], outputs=[model_output])

# loss function & optimizer
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# show model construction
model.summary() #We can notice that our parameter numbers went up because of the increase in the dimension of our input
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 768)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │          49,216 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu (ReLU)                         │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │           4,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu_1 (ReLU)                       │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 6)                   │             390 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ softmax (Softmax)                    │ (None, 6)                   │               0 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 53,766 (210.02 KB)
#  Trainable params: 53,766 (210.02 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

classes = label_encoder.classes_
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train),
    y=y_train
)

from keras.callbacks import CSVLogger

csv_logger = CSVLogger('training_log_2_ts2.csv')

# training setting
epochs = 25
batch_size = 32

class_weight_dict = {i: w for i, w in enumerate(class_weights)}
print(class_weight_dict)
history = model.fit(
    X_embgemma_train, y_train_embgemma,
    epochs=epochs,
    batch_size=batch_size,
    validation_data=(X_embgemma_test, y_test_embgemma),
    class_weight=class_weight_dict
)
# Out:
# {0: 0.5297518857926563, 1: 4.788813750352212, 2: 2.8198938111830096, 3: 0.5723546844480366, 4: 1.4429869247750042, 5: 0.90195297988643}
# Epoch 1/25
# 1063/1063 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.6672 - loss: 0.6482 - val_accuracy: 0.6672 - val_loss: 0.8480
# Epoch 2/25
# 1063/1063 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6725 - loss: 0.6353 - val_accuracy: 0.6779 - val_loss: 0.8166
# Epoch 3/25
# 1063/1063 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - accuracy: 0.6737 - loss: 0.6237 - val_accuracy: 0.6872 - val_loss: 0.7932
# Epoch 4/25
# 1063/1063 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.6814 - loss: 0.6102 - val_accuracy: 0.6597 - val_loss: 0.8604
# Epoch 5/25
# 1063/1063 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.6899 - loss: 0.5893 - val_accuracy: 0.6860 - val_loss: 0.8199
# Epoch 6/25
# 1063/1063 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6865 - loss: 0.5977 - val_accuracy: 0.7033 - val_loss: 0.7649
# Epoch 7/25
# 1063/1063 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.6934 - loss: 0.5805 - val_accuracy: 0.7039 - val_loss: 0.7618
# Epoch 8/25
# 1063/1063 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.6963 - loss: 0.5771 - val_accuracy: 0.7228 - val_loss: 0.7092
# Epoch 9/25
# 1063/1063 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.7037 - loss: 0.5495 - val_accuracy: 0.7322 - val_loss: 0.6816
# Epoch 10/25
# 1063/1063 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.7041 - loss: 0.5489 - val_accuracy: 0.7195 - val_loss: 0.7129
# Epoch 11/25
# 1063/1063 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.7094 - loss: 0.5384 - val_accuracy: 0.7329 - val_loss: 0.6895
# Epoch 12/25
# 1063/1063 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.7167 - loss: 0.5217 - val_accuracy: 0.7213 - val_loss: 0.7213
# Epoch 13/25
# 1063/1063 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.7170 - loss: 0.5296 - val_accuracy: 0.7367 - val_loss: 0.6647
# Epoch 14/25
# 1063/1063 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7256 - loss: 0.5061 - val_accuracy: 0.7378 - val_loss: 0.6769
# Epoch 15/25
# 1063/1063 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7212 - loss: 0.5162 - val_accuracy: 0.7444 - val_loss: 0.6505
# Epoch 16/25
# 1063/1063 ━━━━━━━━━━━━━━━━━━━━ 2530s 2s/step - accuracy: 0.7304 - loss: 0.4906 - val_accuracy: 0.7278 - val_loss: 0.6975
# Epoch 17/25
# 1063/1063 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7358 - loss: 0.4740 - val_accuracy: 0.7382 - val_loss: 0.6514
# Epoch 18/25
# 1063/1063 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.7374 - loss: 0.4753 - val_accuracy: 0.7203 - val_loss: 0.7098
# Epoch 19/25
# 1063/1063 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7341 - loss: 0.4886 - val_accuracy: 0.7133 - val_loss: 0.7417
# Epoch 20/25
# 1063/1063 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7403 - loss: 0.4653 - val_accuracy: 0.7422 - val_loss: 0.6856
# Epoch 21/25
# 1063/1063 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7434 - loss: 0.4627 - val_accuracy: 0.7654 - val_loss: 0.6032
# Epoch 22/25
# 1063/1063 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7513 - loss: 0.4480 - val_accuracy: 0.7669 - val_loss: 0.5974
# Epoch 23/25
# 1063/1063 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7507 - loss: 0.4452 - val_accuracy: 0.7569 - val_loss: 0.6211
# Epoch 24/25
# 1063/1063 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7567 - loss: 0.4356 - val_accuracy: 0.7419 - val_loss: 0.6474
# Epoch 25/25
# 1063/1063 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7563 - loss: 0.4337 - val_accuracy: 0.7597 - val_loss: 0.6058

# %%
pred_result = model.predict(X_embgemma_test, batch_size=128)
pred_result[:5]
# Out:
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
# array([[5.5498141e-01, 1.0753882e-01, 3.2626979e-02, 5.8747772e-02,
#         2.4121624e-01, 4.8888130e-03],
#        [9.5998687e-01, 2.7651670e-03, 6.6824647e-08, 1.7304745e-02,
#         1.8745273e-02, 1.1978751e-03],
#        [7.4728411e-01, 9.5046246e-03, 7.9116747e-02, 3.9608382e-02,
#         6.2896130e-03, 1.1819645e-01],
#        [2.1223843e-03, 6.9035950e-13, 7.5950351e-07, 8.1219143e-01,
#         9.4558673e-06, 1.8567599e-01],
#        [5.2916890e-01, 1.0710889e-05, 1.5340701e-02, 1.6817927e-01,
#         1.9681537e-01, 9.0484999e-02]], dtype=float32)

# %%
pred_result = label_decode(label_encoder, pred_result)
pred_result[:10]
# Out:
# array(['anger', 'anger', 'anger', 'joy', 'anger', 'fear', 'fear', 'anger',
#        'anger', 'joy'], dtype=object)

# %%
from sklearn.metrics import accuracy_score
#Accuracy
print('testing accuracy: {}'.format(round(accuracy_score(label_decode(label_encoder, y_test_embgemma), pred_result), 2)))
# Out:
# testing accuracy: 0.68

# %%
# Funciton for visualizing confusion_matrix
import itertools
import seaborn as sns

def plot_confusion_matrix(cm, classes, title='Confusion matrix',
                          cmap=sns.cubehelix_palette(as_cmap=True)):
    """
    This function is modified from:
    http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html
    """
    classes.sort()
    tick_marks = np.arange(len(classes))

    fig, ax = plt.subplots(figsize=(5,5))
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           xticklabels = classes,
           yticklabels = classes,
           title = title,
           xlabel = 'Predicted label',
           ylabel = 'True label')

    fmt = 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")
    ylim_top = len(classes) - 0.5
    plt.ylim([ylim_top, -.5])
    plt.tight_layout()
    plt.show()

# %%
## check by confusion matrix
from sklearn.metrics import confusion_matrix

cm3 = confusion_matrix(y_true=label_decode(label_encoder, y_test_embgemma), y_pred=pred_result) 
my_tags = ['anger','disgust', 'fear', 'joy', 'sadness','surprise']
plot_confusion_matrix(cm3, classes=my_tags, title='Confusion matrix for classification with \nLLM Embeddings - Neural Network')

# %%
testt_df = test_df[test_df["embeddings"].apply(lambda x: len(x) == 768)]
testt_df = testt_df.reset_index(drop=True)

# %%
X_test = np.vstack(testt_df["embeddings"].values)

# %%
pred_probs = model.predict(X_test)
# Out:
# 509/509 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step

# %%
id2label = {
    0: "anger",
    1: "disgust",
    2: "fear",
    3: "joy",
    4: "sadness",
    5: "surprise"
}

# %%
pred_indices = np.argmax(pred_probs, axis=1)

# %%
import numpy as np

# Convert embeddings to proper 2D array
X_test = np.vstack(testt_df['embeddings'].to_numpy())

# Make predictions
pred_probs = model.predict(X_test)               # shape: (num_samples, num_classes)
pred_classes = np.argmax(pred_probs, axis=1)     # get class indices

# Map back to original emotion labels
testt_df['emotion'] = label_encoder.inverse_transform(pred_classes)

# Check first few rows
final = testt_df[['id','emotion']]
final.to_csv("submit_13.csv")
# Out:
# 509/509 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step

# %%
# assume df has: text, emotion, clean_text
train_df_orr = pd.DataFrame()
train_df_orr['text_clean'] = train_df_or['text_clean'].astype(str)
train_df_orr["emotion"] = train_df_or["emotion"]
# split into words
train_df_orr['words'] = train_df_orr['text_clean'].str.split()

# group by emotion and get unique words per group
unique_words_per_emotion = train_df_orr.groupby('emotion')['words'].apply(
    lambda x: set(word for words in x for word in words)
)

unique_words_per_emotion
# Out:
# emotion
# anger       {@trubble1127, wl, planet,, controls", anu, re...
# disgust     {covered, doxxed, bureaucrat, repair, deserves...
# fear        {unfurls, covered, ancient, planet,, maturely,...
# joy         {wl, #tryit, we'll, news., properties., macos,...
# sadness     {covered, intj, example., direction, term,, im...
# surprise    {covered, intj, ancient, direction, anchors".,...
# Name: words, dtype: object

# %%
common_words=unique_words_per_emotion["disgust"] - unique_words_per_emotion["anger"] - unique_words_per_emotion["fear"] - unique_words_per_emotion["joy"]  - unique_words_per_emotion["sadness"] - unique_words_per_emotion["surprise"]
common_words
# Out:
# {'country).',
#  'hys',
#  'doxxed',
#  'non-native',
#  'sticky"',
#  'politicl',
#  '@joshgad',
#  'trim',
#  'ariel...',
#  'treacherous',
#  '*opens',
#  'troo,',
#  'wikihow,',
#  'synagogue.',
#  'papaoutai',
#  'celebs,',
#  'antidiarrheals.',
#  '@statedept',
#  'iphone.',
#  'superior,',
#  '@jack_haug_lifty',
#  'bingo,',
#  'written??',
#  'yooo',
#  '#sadiqkhan',
#  '#amarnathterrorattack',
#  'incest.',
#  'if(on_earth)',
#  '@iamnotatwit',
#  'amusement.',
#  'recruitment',
#  'paradox',
#  'favorite:',
#  'elseworlds',
#  '#russianhacking',
#  '#wakeupcall',
#  'shade,',
#  'ddr,',
#  '#dailyfeels',
#  'petry',
#  '#vanre',
#  '@lyricconcert',
#  'sides,',
#  '@csnhayes',
#  'diapers.',
#  '14:49',
#  'gele',
#  'tiles.',
#  '@theurbanologist',
#  '@susanbrodigan',
#  'lapses',
#  '#what',
#  'nononononoyes',
#  '#misonorotta',
#  '2/20',
#  'characteristics,',
#  '#radical',
#  'vas',
#  'architecture,',
#  '“training”',
#  'niceties',
#  'chafford',
#  'scentsy',
#  'gone,not',
#  'vomit.',
#  "'accidentally'",
#  '"generic"',
#  'generate',
#  'umbrella',
#  'old--i',
#  'toenails',
#  'davies',
#  'qmos',
#  '#500thtest',
#  'movie.\\n',
#  'systematic.',
#  'behold',
#  'spree.',
#  '“internet',
#  'a***a',
#  '#islamic',
#  '\\n#northcarolina',
#  '#refugees.',
#  'declined',
#  "debtor's",
#  '@patblanchfield',
#  'nouns!',
#  'self-insert/wish',
#  'settles',
#  'arround',
#  'greens',
#  'celulose.',
#  'disgusted,',
#  'self-interest',
#  'infidels?',
#  '@laurakfillault',
#  '@dinohyogi',
#  'possibly,',
#  '@radiox',
#  'ovet',
#  '5v3',
#  '@bsmarz22',
#  '#major',
#  'odi',
#  '5679787.',
#  'sociopath',
#  'lysol',
#  'next..',
#  'carriages',
#  'dishes,',
#  'baddest',
#  'plowing',
#  'catacombs',
#  'croissant',
#  'perpetuating',
#  'powers?',
#  'forgiving',
#  'hakyeon',
#  'unexpectedly',
#  'headed.',
#  'doorjambs.',
#  'bissexual',
#  'undergrads.',
#  'disputed.',
#  'viability',
#  '#fall',
#  'practice…',
#  'skyzone',
#  'glitter',
#  'troo....worse',
#  '‘orwellian’',
#  'eugh',
#  '@twinninglife111',
#  'submissive?',
#  'shadiness',
#  'bannner',
#  'crescent',
#  '@scottinsc',
#  'editorially',
#  '@tonyattah',
#  '#petty',
#  "'genocide',",
#  '#thinktoomuch',
#  'menus,',
#  '#doubt,',
#  'been.”',
#  'conformity,',
#  'prties',
#  '#wow',
#  '%99',
#  "f'n",
#  'credit...',
#  'visit...ugh',
#  '@messyourself',
#  'allergies',
#  'turbo',
#  'prospect',
#  '"capitulate"',
#  'thy',
#  'deport',
#  'value/',
#  'affliction?',
#  '@carlymarierozy',
#  'clutterfuckedd',
#  'cant’t',
#  '$50',
#  'patched',
#  'jaehwan',
#  'worse*',
#  'rhapsody',
#  '@walespolitics',
#  '“was”',
#  '“voters”',
#  'addict\\n&gt;',
#  'distilled,',
#  'hoody,',
#  'goober',
#  'dpt',
#  'racial-blind',
#  '@marksandspencer',
#  'guanxi',
#  'u/hellseashell,',
#  '@londonmidland',
#  'belts',
#  'low-iq,',
#  '@gambieranger',
#  'configurations?',
#  'tyt',
#  'kik/snapchat',
#  '@raylewis',
#  'awfulness,',
#  'lbvfs',
#  '@narcissusheiyan',
#  '@lbc',
#  '#srry',
#  'awake.',
#  '@partydelightsuk',
#  'pepto',
#  'childhood—adults’',
#  'laureliver',
#  'amaity',
#  'stink.',
#  'establishment.',
#  'carpet!!',
#  'wince',
#  'night"',
#  '@haven',
#  '#pakistani',
#  '#college',
#  'returner',
#  'foreskin',
#  'included?',
#  'slut',
#  '@cupidpoetry',
#  "'oh.'",
#  'discharge,',
#  'fetal',
#  'anime.',
#  '#ntac',
#  '6,',
#  '@bentleysystems',
#  'avg',
#  'tomboys.',
#  'pretended',
#  'eating...',
#  'schade',
#  'penalty,',
#  '—but',
#  'concussions',
#  'accountant...',
#  '@r0ils',
#  '@coltonflurry',
#  '#lestweforget',
#  '#kindness!',
#  'distracted.',
#  'paul.should',
#  '@_iconceitedone_',
#  'him/her,',
#  'disgusting...',
#  'avatar,',
#  'gpa',
#  'jerks.',
#  '@ix_sw',
#  '#gascrisis2016',
#  '😒💁🏻',
#  'safe...?',
#  'deduced',
#  '#events',
#  'pennies,',
#  'funny/offensive',
#  '@naynay_whores',
#  'filthy.',
#  'hookup',
#  'sunglasses.',
#  'musty',
#  'oppa',
#  '@cazual_wear',
#  '@rainbow6game',
#  'dad...',
#  '@_jessicavidal_',
#  '@haideralabadi',
#  "you'\\nwrdsmth",
#  '#distraction',
#  '@m_pattison',
#  'iraq',
#  'niche',
#  'moon?).',
#  'gloom,',
#  '@officeofrg',
#  'ssd',
#  '18:41',
#  'goop',
#  '@sainsburys',
#  'steamboat',
#  'morrow',
#  'shook,',
#  'caustic',
#  'worrysome.',
#  'chaser',
#  'studies--',
#  'disgraceful.',
#  "break.'",
#  'better2day',
#  '02',
#  '#ridicule,',
#  'bump.',
#  'scat',
#  '#expecting',
#  '"fascist',
#  '#regret',
#  'tiff.',
#  'vic.',
#  'movies?',
#  '#lifecoach',
#  'faint.',
#  'localities',
#  '@lraitt',
#  'anniversary,',
#  '#wewait',
#  'bode',
#  'penis.......',
#  'cartridge??',
#  '*that*',
#  'costly.',
#  'battered.',
#  'hatred.',
#  'years—hasn’t',
#  'fastest.',
#  'ships.',
#  'puppies)',
#  '#shape',
#  'experimental',
#  '“good.”',
#  'disagree!',
#  '>implying',
#  'ignorance!',
#  '@paramjitgarewal',
#  '#nodapl',
#  "facebook's",
#  '#whitepeople',
#  '~~weak',
#  'hereford',
#  '@kayleighmcenany',
#  '@sherrieshepherd',
#  'hire-able',
#  "nicole's",
#  'trainee',
#  'paneling?',
#  'generation,',
#  'trope.',
#  'morning.......',
#  '@swp_roads',
#  '#startingover',
#  '#shouldhavebeenhufflepuff',
#  'iraqi',
#  "thing's",
#  "pandora's",
#  'slob',
#  '(spiritual',
#  '@pmo100',
#  '#snap.',
#  ";'(\\n#pictureday2016",
#  'jealousy.',
#  '>morality',
#  'door\\na',
#  'menacing',
#  'sucker,',
#  'fateful',
#  'saying:',
#  'only)',
#  "woman's,",
#  '@xmaseveevil1.',
#  '#everyday',
#  'hurtful',
#  'revelations',
#  'shining!',
#  'reproduced.',
#  '#badkarma',
#  '#worstenemy',
#  '@lululemonlime83',
#  'fulfillment.',
#  "accountability'",
#  'us."',
#  '#anthonyweiner',
#  'followers.',
#  'diazepam',
#  'maiming',
#  'protests.',
#  'hairstyle',
#  'liquids.',
#  'ribbons',
#  "phone!!!'",
#  'idealogues',
#  "o'",
#  'wheelchair',
#  'penetrated',
#  'roleplay.',
#  'fakes',
#  'rasty',
#  '@doge_e_fresh',
#  'prisoned',
#  'undeveloped/deformed',
#  'chairman’s',
#  'unlikely.',
#  'wishhhh.',
#  '89th',
#  'stage,',
#  'hikes,”',
#  'crumbs',
#  '@nigeriainfofm',
#  'vomiting,',
#  'creek',
#  'instigator',
#  'pothole.',
#  'less)',
#  '@karenl109',
#  '“like',
#  'accent???',
#  'unadulterated',
#  'hijab',
#  '#longing',
#  'turd.',
#  '#disappointed',
#  'vpn?',
#  'extremes',
#  '#msm',
#  "trump's",
#  'sting/title',
#  "head.'\\n\\n",
#  'vicious.',
#  'bicycle',
#  'fosu-mensa',
#  'spare,',
#  'fur',
#  'swallowed.',
#  'doomed.',
#  'citizenship',
#  'immune',
#  'gloomy.',
#  'tedious',
#  'trait',
#  '@malkarii_',
#  '#selection',
#  'dvlpt',
#  'fumbles',
#  'employies',
#  '2016;',
#  'compositional',
#  'derogatory',
#  'motherfucker,',
#  '7am',
#  '#that',
#  'fetishists',
#  "'bye,",
#  'clash',
#  'tyre',
#  'evangelical,',
#  'febreeze',
#  '@flakejay',
#  'ppl,',
#  'married😭',
#  '@byekandace',
#  'oughta',
#  'spectacles',
#  'intervation',
#  "can't!",
#  'blessing',
#  '*ugh..*',
#  'mayonnaise,',
#  'internship.',
#  '(-:',
#  '"we\'ve',
#  'ew😅',
#  'phew!!',
#  '>"fuck',
#  'tribalism',
#  'filth.',
#  'tehe...creamed',
#  'hawkings',
#  'ass"',
#  '#respect',
#  'yearly',
#  '@virendersehwag',
#  'going\\nto',
#  'swings.',
#  'close-out,',
#  '@kapilsharmak9',
#  'having.',
#  '#saidnondnever.',
#  '#rocktheretweet',
#  '6:30',
#  'anus',
#  'grafx',
#  'shake,',
#  'disgrace!',
#  'ex...',
#  'reich',
#  'perpetually',
#  "peoples'",
#  '@mrsfridaynext',
#  '@fra93_bruno',
#  'cringey,',
#  'sacrilegious',
#  'well-being',
#  'comparisons',
#  'rule,nimber',
#  '@tfunion1111',
#  'pooed',
#  'harm.',
#  'execution.',
#  '@netflix_me',
#  'tannery',
#  'often.\\n\\nchurch',
#  'evrn',
#  'jerk,',
#  'varies-',
#  'banality',
#  '@katheartwell',
#  'máxima.',
#  '"son',
#  "'moist'",
#  'days?\\nbogum:',
#  'huns.',
#  '❤︎i...',
#  'seat!',
#  'grimy',
#  "me\\nit's",
#  'colorful',
#  'smile*\\nconclusion:',
#  'penetrated.',
#  'bush...no',
#  'difficulty?',
#  'boyo',
#  'breeders',
#  'tunnels!',
#  '#worry,',
#  '@bigdaddyx47',
#  'cliche.',
#  '#whileyouweresleeping',
#  'artemis',
#  '#asleep',
#  'arrogantly',
#  'beating-a-little-girl-thing',
#  '@fitzstockcharts',
#  'porkistan',
#  'one-size-fits-all…',
#  'cleaning!!!',
#  '10mcg',
#  'fascist."',
#  'reloading',
#  'doubles',
#  'cracker',
#  '#brunei',
#  'old😩💔',
#  'gardeners',
#  '@joaquinputoamo',
#  '#london.',
#  'fandom',
#  'pos.',
#  'pant',
#  '#filthy',
#  'dirtiness',
#  'hodgson',
#  'jackets',
#  'motions.',
#  'fuck!',
#  'baseball/football/basketball',
#  'serious??',
#  'zelda',
#  'maths',
#  'sad!!',
#  'carapace',
#  'detriment',
#  'act.',
#  'anoint',
#  'bernards.',
#  'spills',
#  '#ignorant',
#  'days?!?!',
#  'magatards.',
#  "'@innocentia_t:",
#  '#afghan',
#  '#autodealerlive,',
#  '@royalmusing',
#  'punches',
#  "'model'",
#  'ladies.',
#  '#nicole',
#  'her!!',
#  "spinnin'",
#  'right...ugly',
#  'genitals',
#  'definitively',
#  '@bigbosspeltonen',
#  '"she’s',
#  'exist!',
#  '@robertb_rice',
#  'revolves',
#  'yes-',
#  'trashier',
#  '#rat\\nam',
#  '...\\ni',
#  'grossest',
#  '@itdominiccoyle',
#  'pretending.',
#  'mongoose',
#  '@esanderc',
#  'village—outsiders',
#  'haked',
#  'ravenclaw.',
#  '[my',
#  'eban',
#  'delirium',
#  'miz',
#  '@kevincanwaitcbs',
#  'pedal',
#  '#shouldofgonewithvirgin',
#  '#history',
#  'fumbles....',
#  '#perilous',
#  'shithole',
#  'jure',
#  '@simonschuster',
#  '@crimsonwulfe',
#  '@wysdaily',
#  '-30°,',
#  'maybe...',
#  '@thefrankjlopes',
#  'hell...',
#  'accent).',
#  '“f”',
#  '@macadamionnut',
#  'wii.',
#  '@bonesarp',
#  'stresses',
#  '😩😔😭😞',
#  "own'",
#  'julian',
#  'hollywood?',
#  'denial:',
#  '@jwonder81',
#  '@moneyjay901',
#  'ingest',
#  'friday.',
#  'people/society.',
#  'unintentional',
#  '2003',
#  'simmering',
#  'antwaarps',
#  'waive',
#  ',or',
#  'scripture',
#  'hideous.',
#  '#martyrsnotbeggars',
#  'smutty',
#  'guarenteed',
#  'goldman',
#  '@aqpk',
#  '#pok?',
#  'does...',
#  'queue,',
#  '#worstcelebritycooks',
#  'err',
#  '@ilovetailgating',
#  'vaguely',
#  "'your",
#  '#katherinemansfield',
#  'crowder.',
#  'wed',
#  'adam,',
#  'o,',
#  'corn....',
#  'him..',
#  'companys',
#  'bits.',
#  'today...i',
#  'baiting',
#  'tacos!',
#  "child's",
#  "'friends'",
#  '@steadi_lady',
#  'lindsey',
#  '@chic_happens_',
#  'charlkboard',
#  '#nawazfightsforkashmir',
#  '“news”',
#  'stk',
#  '#party',
#  'mint.',
#  'malt',
#  '@thecatcampbell',
#  '#boredaf',
#  '#riots',
#  'sandals.',
#  '#cashback',
#  'stevie',
#  'evolution.',
#  'kidnapped.',
#  'algeria',
#  "'dancing",
#  'guns,',
#  '😂😂😂😂😂😂😂😂😂😂😂😂😂😂',
#  'vacuum',
#  '😭💔',
#  '@strong_bread',
#  'low/',
#  'girl?!',
#  'cigar.',
#  'criticizes',
#  'but...yikes!',
#  'have"',
#  '@tbergg1',
#  'bars?',
#  'divisive.',
#  'circumcision.',
#  '@vivaonline',
#  'troll...',
#  'hilarity,',
#  '@hotrodarchie',
#  'secondly,',
#  '"allergy:',
#  'remus',
#  'theorists',
#  'man"-',
#  '#rainbowsixsiege',
#  '#warrior',
#  'childhood”',
#  'mean-spirited.',
#  'procedures!(end',
#  'dictionaries',
#  'videos,',
#  'opstn.',
#  '@vladfucker69',
#  'viable',
#  '#emoji',
#  '☹️️',
#  'participation',
#  'definitions.',
#  'infrastructure.',
#  'doozy.',
#  '@kerophibian',
#  'some-would-say-successful',
#  'feathers,',
#  '3?',
#  'u/reijka92',
#  'tinder,',
#  '#ornot',
#  "'algebra'",
#  'legislatively,',
#  'deselect',
#  '"merit."',
#  'iso',
#  'donatists',
#  '17.2',
#  'poop.',
#  'hideous',
#  '@essdotx',
#  'err,',
#  '(1977)\\na',
#  'bating',
#  '*do',
#  'dumps',
#  '“toffs”',
#  'dismay.',
#  "barb's",
#  '@mbna',
#  '#entitlement',
#  'deloitte',
#  ':):)',
#  'maturity',
#  'brutality,',
#  '29?',
#  '"honoring"',
#  "'personal",
#  'sexists',
#  'mess!!!',
#  'mea.',
#  'smile*\\nme',
#  "'scrape'.",
#  '@twinfjournal',
#  '(legal)',
#  '#ampalaya',
#  '@5livesport',
#  'happy..',
#  '"song"',
#  'korgoth',
#  'leftie',
#  'abo',
#  "do?'\\n'you",
#  'caught,',
#  'edt)',
#  'jt',
#  '#foh',
#  'slaves,',
#  'disease!',
#  '@nigerialng',
#  'heyday.',
#  'eric',
#  '"lazy',
#  'hag.',
#  'eww.',
#  'masturbating.',
#  "girlfriend's",
#  ".'",
#  'explicit',
#  '🐑',
#  'mushroom',
#  'unofficially',
#  'shooed',
#  '*secretly',
#  'condescension',
#  'with."',
#  'reserves',
#  'lewis',
#  'purposeful',
#  'off...?',
#  '#hipocrite',
#  'factory.',
#  'beguile',
#  '5/10',
#  'kashmir',
#  'exsists.',
#  '@mickeyrourkefp',
#  '#letdown',
#  'snaps/insta',
#  'negro',
#  'frisky',
#  '@purenift',
#  '@megalvz',
#  '#ahsaftershow',
#  'incel?',
#  'moonwolf1-799',
#  'squish',
#  'silence=complicity.',
#  '“diversity”',
#  '0/5',
#  'still?',
#  'isekai',
#  'idgi',
#  'vertebrates',
#  'lawyers.',
#  "70's",
#  'scared!',
#  'dubious',
#  'blasphemy.',
#  'outlier.',
#  'pajamas',
#  '----',
#  '#accidentlyspillbeeronthecarpet',
#  'commentators',
#  '50yrs.',
#  "garbage!'",
#  'breaths',
#  'xenophobic',
#  'egregious',
#  '#gotham.',
#  'cisco',
#  'hast',
#  'tyl',
#  'despondent',
#  '@mcauley_ross',
#  'pleasant.',
#  'firerocket();',
#  '#path\\nbut',
#  'vonn',
#  '*shudders*',
#  'horseman:',
#  '\\n&gt;',
#  'disgusting!”',
#  'equals',
#  '@david__osland',
#  'guess”',
#  'despair!',
#  '#failure',
#  't20',
#  'fudds.',
#  '#loneliness',
#  '#snapchatme',
#  'afp.',
#  '#kikmessage',
#  '5/5',
#  'bismol',
#  'shitstorm',
#  'ranch,',
#  'his—',
#  '@outdoorloverz',
#  'grungy',
#  'appendix',
#  'runoff',
#  'cryptic',
#  "challenge'",
#  '1749485',
#  'ferdinand',
#  'processing.',
#  'gormless',
#  '#aloneinthecity',
#  'presentations',
#  '15%',
#  '“yeah',
#  '@qadkins79',
#  'sink.',
#  'crackers',
#  '@cohends',
#  'kylexy',
#  'terrorizes',
#  '#the',
#  'filmmaker',
#  'fuckin’',
#  'scumbags.',
#  '@amityaffliction',
#  'viewpoint.',
#  'hellraiser',
#  'chooks.',
#  '#welfarereform',
#  '@mickyrivera29',
#  'vitara',
#  'votes,',
#  '*awkward',
#  'meltdowns',
#  'starch',
#  'blameless?',
#  'franz',
#  'sao',
#  '^^^:^^^p',
#  "disappointment.'\\n\\nhe",
#  '@cbsthismorning',
#  'tab*',
#  'mio',
#  'outside!',
#  'morgue,',
#  'awkward...',
#  'civilians.',
#  'adversely',
#  '@komaebun',
#  'uggh',
#  'because???',
#  'sav',
#  'bathe',
#  'wif',
#  'escalation',
#  "wonshik's",
#  "bees!'",
#  'right!\\n',
#  'more)',
#  'pessimistic.',
#  'eu,',
#  'dissociating',
#  'swb',
#  '@jdwmaguire',
#  'neckbeards',
#  'lagos',
#  'normalize.',
#  'form?',
#  'lonely?',
#  'piece!',
#  "'muricans",
#  'writers,',
#  'trixie.',
#  'aht',
#  'bruise',
#  'wifebeaters',
#  'dark.',
#  'legislator',
#  '^roberts',
#  'vampired',
#  '04',
#  "driver'",
#  'integrated,',
#  'fleshy',
#  'nosed',
#  'dealerships',
#  'galore',
#  'theatrical',
#  '@the',
#  'sense?',
#  '#dealingwithfailure',
#  'scarf',
#  'striving.',
#  'end!',
#  'suck!!',
#  '#cujo',
#  "spencer's",
#  '>+.',
#  'tobacco',
#  'manure.',
#  'swiping',
#  'reboot',
#  'akot',
#  'cellular',
#  '#countrygirl',
#  '#martinshkreli.',
#  'reams',
#  '@realmatkoenig',
#  'affliction.',
#  '80s,',
#  'bussing',
#  'throat:',
#  'redhead',
#  'moralising',
#  '#like',
#  'gossip',
#  'journals,',
#  'planning!',
#  'iranian',
#  '@rosalilium',
#  'fundraisers!',
#  '@awardsdaily',
#  'cultivating',
#  'empty;',
#  '@amexuk',
#  'untested',
#  'neigh',
#  'unreliable.',
#  'belief,',
#  'sexes',
#  'creature.',
#  'texts.',
#  'refused,',
#  'inflicted',
#  'hardhomme!',
#  ...}

# %% [markdown]
# ## 3. Model Implementation Steps

# %%
### Add the code related to the model implementation steps in cells inside this section
